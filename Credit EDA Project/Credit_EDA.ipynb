# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
credit = pd.read_csv("/content/drive/MyDrive/WTF-Material_Class B/credit_train(in) (1).csv")
credit.tail(3)
# Out:
#                                     Loan ID  \
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
# 99998  81ab928b-d1a5-4523-9a3c-271ebb01b4fb
# 99999  c63916c6-6d46-47a9-949a-51d09af4414f
#
#                                 Customer ID Loan Status  Current Loan Amount  \
# 99997  2ced5f10-bd60-4a11-9134-cadce4e7b0a3  Fully Paid               103136
# 99998  3e45ffda-99fd-4cfc-b8b8-446f4a505f36  Fully Paid               530332
# 99999  1b3014be-5c07-4d41-abe7-44573c375886  Fully Paid             99999999
#
#              Term  Credit Score  Annual Income Years in current job  \
# 99997  Short Term         742.0      1150545.0              6 years
# 99998  Short Term         746.0      1717524.0              9 years
# 99999  Short Term         743.0       935180.0                  NaN
#
#       Home Ownership             Purpose  Monthly Debt  \
# 99997           Rent  Debt Consolidation       7315.57
# 99998           Rent  Debt Consolidation       9890.07
# ...

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS (EDA)**

# %%
#checking for the count of duplicate values

credit.duplicated().sum()
# Out:
# np.int64(10215)

# %%
#remove the duplicated rowsfor the dataframe and also check for the new dimension of the dataframe

credit.drop_duplicates(inplace=True)
credit.shape
# Out:
# (89785, 19)

# %%
#generate descriptive ztatistics of the dataset

credit.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         8.978500e+04  70631.000000   7.063100e+04   89785.000000
# mean          1.306089e+07   1130.830598   1.375894e+06   18396.906410
# std           3.329556e+07   1571.037395   1.104852e+06   12145.282372
# min           1.080200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.802680e+05    708.000000   8.479320e+05   10157.400000
# 50%           3.138740e+05    729.000000   1.168975e+06   16140.310000
# 75%           5.323780e+05    742.000000   1.648915e+06   23918.910000
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count             89785.000000                  41448.000000
# mean                 18.248642                     34.975873
# std                   7.034607                     22.008585
# min                   3.600000                      0.000000
# ...

# %%
credit.isnull().sum()
# Out:
# Loan ID                             0
# Customer ID                         0
# Loan Status                         0
# Current Loan Amount                 0
# Term                                0
# Credit Score                    19154
# Annual Income                   19154
# Years in current job             3802
# Home Ownership                      0
# Purpose                             0
# Monthly Debt                        0
# Years of Credit History             0
# Months since last delinquent    48337
# Number of Open Accounts             0
# Number of Credit Problems           0
# Current Credit Balance              0
# Maximum Open Credit                 2
# Bankruptcies                      190
# Tax Liens                           9
# dtype: int64

# %%
credit.isna().sum()
# Out:
# Loan ID                             0
# Customer ID                         0
# Loan Status                         0
# Current Loan Amount                 0
# Term                                0
# Credit Score                    19154
# Annual Income                   19154
# Years in current job             3802
# Home Ownership                      0
# Purpose                             0
# Monthly Debt                        0
# Years of Credit History             0
# Months since last delinquent    48337
# Number of Open Accounts             0
# Number of Credit Problems           0
# Current Credit Balance              0
# Maximum Open Credit                 2
# Bankruptcies                      190
# Tax Liens                           9
# dtype: int64

# %%
#observation of all the columns

credit.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
#summary of all the columns

def check(df):
  l=[]
  columns =df.columns
  for col in columns:
    dtypes=df[col].dtypes
    shape=df[col].shape
    nunique=df[col].nunique()
    sum_null=df[col].isnull().sum()
    l.append([col,dtypes,nunique,shape,sum_null])
  df_check=pd.DataFrame(l)
  df_check.columns=["columns", "dtypes", "nunique", "shape", "sum_null"]
  return df_check
check(credit)
# Out:
#                          columns   dtypes  nunique     shape  sum_null
# 0                        Loan ID   object    81999  (89785,)         0
# 1                    Customer ID   object    81999  (89785,)         0
# 2                    Loan Status   object        2  (89785,)         0
# 3            Current Loan Amount    int64    22004  (89785,)         0
# 4                           Term   object        2  (89785,)         0
# 5                   Credit Score  float64      324  (89785,)     19154
# 6                  Annual Income  float64    36174  (89785,)     19154
# 7           Years in current job   object       11  (89785,)      3802
# 8                 Home Ownership   object        4  (89785,)         0
# 9                        Purpose   object       16  (89785,)         0
# 10                  Monthly Debt  float64    65765  (89785,)         0
# 11       Years of Credit History  float64      506  (89785,)         0
# ...

# %%
credit.head(10)
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
# 5  89d8cb0c-e5c2-4f54-b056-48a645c543dd  4ffe99d3-7f2a-44db-afc1-40943f1f9750
# 6  273581de-85d8-4332-81a5-19b04ce68666  90a75dde-34d5-419c-90dc-1e58b04b3e35
# 7  db0dc6e1-77ee-4826-acca-772f9039e1c7  018973c9-e316-4956-b363-67e134fb0931
# 8  8af915d9-9e91-44a0-b5a2-564a45c12089  af534dea-d27e-4fd6-9de8-efaa52a78ec0
# 9  0b1c4e3d-bd97-45ce-9622-22732fcdc9a0  235c4a43-dadf-483d-aa44-9d6d77ae4583
#
#    Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# ...

# %%
#dropping two columns "Loan ID", "Customer ID" because they both have unique data

columns_to_drop = ["Loan ID", "Customer ID"]
existing_columns = credit.columns.intersection(columns_to_drop)
credit.drop(existing_columns, axis = 1, inplace=True)

# %%
credit.drop_duplicates(inplace=True)
credit
# Out:
#       Loan Status  Current Loan Amount        Term  Credit Score  \
# 0      Fully Paid               445412  Short Term         709.0
# 1      Fully Paid               262328  Short Term           NaN
# 2      Fully Paid             99999999  Short Term         741.0
# 3      Fully Paid               347666   Long Term         721.0
# 4      Fully Paid               176220  Short Term           NaN
# ...           ...                  ...         ...           ...
# 99994  Fully Paid               210584  Short Term         719.0
# 99996  Fully Paid             99999999  Short Term         732.0
# 99997  Fully Paid               103136  Short Term         742.0
# 99998  Fully Paid               530332  Short Term         746.0
# 99999  Fully Paid             99999999  Short Term         743.0
#
#        Annual Income Years in current job Home Ownership             Purpose  \
# 0          1167493.0              8 years  Home Mortgage   Home Improvements
# ...

# %%
credit["Purpose"].unique()
# Out:
# array(['Home Improvements', 'Debt Consolidation', 'Buy House', 'other',
#        'Business Loan', 'Buy a Car', 'major_purchase', 'Take a Trip',
#        'Other', 'small_business', 'Medical Bills', 'wedding', 'vacation',
#        'Educational Expenses', 'moving', 'renewable_energy'], dtype=object)

# %%
#the diagram below show the purpose of loan taking

plt.figure(figsize = (15,9))
sns.countplot(x = "Purpose", data = credit, hue = "Loan Status")
plt.xticks(rotation = 90)
plt.title("Purpose of taking load", fontdict={"fontsize":20})
plt.show()

#majority of the loans was taken for Debt Consolidation

# %%
#the image shows the status of loan taken

sns.countplot(x = "Loan Status", data = credit)
# Out:
# <Axes: xlabel='Loan Status', ylabel='count'>

# %%
sns.displot(credit, x = "Loan Status", col = "Term", stat ="density", common_norm = False)

# %%
#annual income by loan term

credit.groupby("Term").agg({"Annual Income":"sum"})
# Out:
#             Annual Income
# Term
# Long Term    2.891753e+10
# Short Term   6.826327e+10

# %%
credit["Annual Income"].median()
# Out:
# 1168975.0

# %%
credit["Annual Income"].mean()
# Out:
# np.float64(1375894.3876909572)

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="Home Ownership", data = credit, hue = "Loan Status")
plt.title("Own property vs loan status", fontdict = {"fontsize":20})
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="Home Ownership", data = credit, hue = "Loan Status")
plt.title("Own property vs loan status", fontsize = 20)
plt.show()
